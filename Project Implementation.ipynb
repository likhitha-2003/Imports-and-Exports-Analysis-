# %% [markdown]
# ### Import the Libraries

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
#imported all the libraries required

# %% [markdown]
# ### Reading the data set

# %%
trade=pd.read_csv("imports and exports.csv")
trade
# Out:
#           Country Exporting Importing Total Trade Trade Balance  \
# 0     AFGHANISTAN     21.25      10.7       31.95         10.55
# 1     AFGHANISTAN     12.81     28.14       40.95        -15.33
# 2     AFGHANISTAN      33.2     21.06       54.26         12.15
# 3     AFGHANISTAN     25.86     26.59       52.45         -0.73
# 4     AFGHANISTAN     24.37     17.52       41.89          6.85
# ...           ...       ...       ...         ...           ...
# 5989     ZIMBABWE    181.72      7.79      189.51        173.93
# 5990     ZIMBABWE    161.13     13.59      174.72        147.54
# 5991     ZIMBABWE    175.72      5.71      181.42        170.01
# 5992     ZIMBABWE    200.49      7.77      208.27        192.72
# 5993     ZIMBABWE     50.17      0.61       50.78         49.57
#
#       Financial Year(start) Financial Year(end)
# 0                      1997                1998
# 1                      1998                1999
# 2                      1999                2000
# ...

# %% [markdown]
# ### Basic functions on data set

# %%
#head() function returns specified no of rows from top

trade=pd.read_csv("imports and exports.csv")
trade.head(10)
# Out:
#        Country Exporting Importing Total Trade Trade Balance  \
# 0  AFGHANISTAN     21.25      10.7       31.95         10.55
# 1  AFGHANISTAN     12.81     28.14       40.95        -15.33
# 2  AFGHANISTAN      33.2     21.06       54.26         12.15
# 3  AFGHANISTAN     25.86     26.59       52.45         -0.73
# 4  AFGHANISTAN     24.37     17.52       41.89          6.85
# 5  AFGHANISTAN     60.77     18.46       79.23         42.31
# 6  AFGHANISTAN    145.47     40.51      185.98        104.96
# 7  AFGHANISTAN    165.44     47.01      212.44        118.43
# 8  AFGHANISTAN    142.67     58.42      201.09         84.24
# 9  AFGHANISTAN    182.11     34.37      216.48        147.73
#
#    Financial Year(start) Financial Year(end)
# 0                   1997                1998
# 1                   1998                1999
# 2                   1999                2000
# 3                   2000                2001
# 4                   2001                2002
# ...

# %%
#tail() function returns specified no of rows from bottom

trade=pd.read_csv("imports and exports.csv")
trade.tail(10)
# Out:
#        Country Exporting Importing Total Trade Trade Balance  \
# 5984  ZIMBABWE    158.06      12.5      170.56        145.56
# 5985  ZIMBABWE    223.96      32.7      256.65        191.26
# 5986  ZIMBABWE    205.09     24.45      229.53        180.64
# 5987  ZIMBABWE    109.08     60.46      169.54         48.63
# 5988  ZIMBABWE    163.54      62.2      225.74        101.34
# 5989  ZIMBABWE    181.72      7.79      189.51        173.93
# 5990  ZIMBABWE    161.13     13.59      174.72        147.54
# 5991  ZIMBABWE    175.72      5.71      181.42        170.01
# 5992  ZIMBABWE    200.49      7.77      208.27        192.72
# 5993  ZIMBABWE     50.17      0.61       50.78         49.57
#
#       Financial Year(start) Financial Year(end)
# 5984                   2013                2014
# 5985                   2014                2015
# 5986                   2015                2016
# 5987                   2016                2017
# 5988                   2017                2018
# ...

# %%
trade.shape # to get current shape
# Out:
# (5994, 7)

# %%
# rename for changing column names
trade=trade.rename({'Importing':'Import','Exporting':'Export'},axis='columns')
trade.head()
# Out:
#        Country Export Import Total Trade Trade Balance  Financial Year(start)  \
# 0  AFGHANISTAN  21.25   10.7       31.95         10.55                   1997
# 1  AFGHANISTAN  12.81  28.14       40.95        -15.33                   1998
# 2  AFGHANISTAN   33.2  21.06       54.26         12.15                   1999
# 3  AFGHANISTAN  25.86  26.59       52.45         -0.73                   2000
# 4  AFGHANISTAN  24.37  17.52       41.89          6.85                   2001
#
#   Financial Year(end)
# 0                1998
# 1                1999
# 2                2000
# 3                2001
# 4                2002

# %%
trade.columns # to get the columns
# Out:
# Index(['Country', 'Export', 'Import', 'Total Trade', 'Trade Balance',
#        'Financial Year(start)', 'Financial Year(end)'],
#       dtype='object')

# %%
trade.dtypes # returns a series with data type of each item
# Out:
# Country                  object
# Export                   object
# Import                   object
# Total Trade              object
# Trade Balance            object
# Financial Year(start)     int64
# Financial Year(end)      object
# dtype: object

# %%
# counting the values ;
# returns a series that contain counts of unique values
# returns object that will be in decending order

trade['Financial Year(start)'].value_counts()
# Out:
# 2019    239
# 2017    238
# 2013    235
# 2004    234
# 2005    234
# 2007    234
# 2010    233
# 2012    233
# 2014    233
# 2020    233
# 2018    233
# 2016    233
# 2008    233
# 2011    233
# 2009    232
# 2006    231
# 2015    231
# 2003    230
# 2021    230
# 2022    225
# 1997    224
# 1998    223
# 2001    223
# 2000    223
# 2002    222
# 1999    222
# Name: Financial Year(start), dtype: int64

# %%
trade.describe() # describe functions returns all these values like mean,count etc..
# Out:
#        Financial Year(start)
# count            5994.000000
# mean             2009.596096
# std                 7.460527
# min              1997.000000
# 25%              2003.000000
# 50%              2010.000000
# 75%              2016.000000
# max              2022.000000

# %% [markdown]
# #### sorting

# %%
trade.sort_values('Financial Year(start)',ascending=False)
# sorted in descending order of financial yr
# Out:
#           Country  Export    Import Total Trade Trade Balance  \
# 5993     ZIMBABWE   50.17      0.61       50.78         49.57
# 4460       RUSSIA  435.59  9,267.03    9,702.63     -8,831.44
# 1192     COLOMBIA  427.91    767.16    1,195.06       -339.25
# 4533        SAMOA    0.21      0.04        0.25          0.18
# 3427      MAYOTTE    0.84      0.39        1.23          0.45
# ...           ...     ...       ...         ...           ...
# 4056  PAKISTAN IR  143.15     44.45       187.6          98.7
# 2827       KUWAIT  178.37    889.79    1,068.16       -711.43
# 393   BAHARAIN IS    61.2    132.93      194.12        -71.73
# 4044   PACIFIC IS    0.02       NaN         NaN           NaN
# 0     AFGHANISTAN   21.25      10.7       31.95         10.55
#
#       Financial Year(start) Financial Year(end)
# 5993                   2022            till now
# 4460                   2022            till now
# 1192                   2022            till now
# ...

# %%
#max() function ; sorting based on highest financial year
trade[trade["Financial Year(start)"]==trade["Financial Year(start)"].max()]
# Out:
#               Country    Export    Import Total Trade Trade Balance  \
# 25        AFGHANISTAN    147.56     94.03      241.58         53.53
# 51            ALBANIA     14.96      2.56       17.51          12.4
# 77            ALGERIA    148.84    332.79      481.62       -183.95
# 103       AMERI SAMOA         0      0.01        0.01         -0.01
# 129           ANDORRA       0.1       NaN         NaN           NaN
# ...               ...       ...       ...         ...           ...
# 5866  VIETNAM SOC REP  1,422.08  2,216.55    3,638.63       -794.47
# 5892     VIRGIN IS US      1.31      0.27        1.58          1.03
# 5941    YEMEN REPUBLC    353.08     43.72      396.79        309.36
# 5967           ZAMBIA     83.55     58.03      141.58         25.52
# 5993         ZIMBABWE     50.17      0.61       50.78         49.57
#
#       Financial Year(start) Financial Year(end)
# 25                     2022            till now
# 51                     2022            till now
# ...

# %%
# unique() function
# to get unique values of series subjects
trade['Import'].unique()
print(len(trade['Import'].unique()))
# Out:
# 3729

# %% [markdown]
# ### Data Cleaning

# %%
trade.isnull() # detects missing values in the given series object
# Out:
#       Country  Export  Import  Total Trade  Trade Balance  \
# 0       False   False   False        False          False
# 1       False   False   False        False          False
# 2       False   False   False        False          False
# 3       False   False   False        False          False
# 4       False   False   False        False          False
# ...       ...     ...     ...          ...            ...
# 5989    False   False   False        False          False
# 5990    False   False   False        False          False
# 5991    False   False   False        False          False
# 5992    False   False   False        False          False
# 5993    False   False   False        False          False
#
#       Financial Year(start)  Financial Year(end)
# 0                     False                False
# 1                     False                False
# 2                     False                False
# 3                     False                False
# ...

# %%
trade.isnull().sum() # counts the no of missing values in each row
# Out:
# Country                    0
# Export                     8
# Import                   552
# Total Trade              585
# Trade Balance            586
# Financial Year(start)      0
# Financial Year(end)        0
# dtype: int64

# %%
# To print the only null values records
trade[trade.isnull().any(axis=1)]
# axis=1 for performing action a column
# Out:
#           Country Export Import Total Trade Trade Balance  \
# 28        ALBANIA   0.91    NaN         NaN           NaN
# 78    AMERI SAMOA   0.06   0.06         NaN           NaN
# 80    AMERI SAMOA   0.59    NaN         NaN           NaN
# 81    AMERI SAMOA   0.71    NaN         NaN           NaN
# 82    AMERI SAMOA   0.19    NaN         NaN           NaN
# ...           ...    ...    ...         ...           ...
# 5907  WALLIS F IS   0.21    NaN         NaN           NaN
# 5908  WALLIS F IS   0.02    NaN         NaN           NaN
# 5911  WALLIS F IS   0.01    NaN         NaN           NaN
# 5913  WALLIS F IS   0.02    NaN         NaN           NaN
# 5915  WALLIS F IS      0    NaN         NaN           NaN
#
#       Financial Year(start) Financial Year(end)
# 28                     1999                2000
# 78                     1997                1998
# 80                     1999                2000
# 81                     2000                2001
# ...

# %%
# notnull()
trade.notnull() # for non-missing values
# Out:
#       Country  Export  Import  Total Trade  Trade Balance  \
# 0        True    True    True         True           True
# 1        True    True    True         True           True
# 2        True    True    True         True           True
# 3        True    True    True         True           True
# 4        True    True    True         True           True
# ...       ...     ...     ...          ...            ...
# 5989     True    True    True         True           True
# 5990     True    True    True         True           True
# 5991     True    True    True         True           True
# 5992     True    True    True         True           True
# 5993     True    True    True         True           True
#
#       Financial Year(start)  Financial Year(end)
# 0                      True                 True
# 1                      True                 True
# 2                      True                 True
# 3                      True                 True
# ...

# %%
# To count the not null records
trade.notnull().sum()
# Out:
# Country                  5994
# Export                   5986
# Import                   5442
# Total Trade              5409
# Trade Balance            5408
# Financial Year(start)    5994
# Financial Year(end)      5994
# dtype: int64

# %%
# To print the not null records.
trade[trade.notnull().all(axis=1)]
# Out:
#           Country  Export Import Total Trade Trade Balance  \
# 0     AFGHANISTAN   21.25   10.7       31.95         10.55
# 1     AFGHANISTAN   12.81  28.14       40.95        -15.33
# 2     AFGHANISTAN    33.2  21.06       54.26         12.15
# 3     AFGHANISTAN   25.86  26.59       52.45         -0.73
# 4     AFGHANISTAN   24.37  17.52       41.89          6.85
# ...           ...     ...    ...         ...           ...
# 5989     ZIMBABWE  181.72   7.79      189.51        173.93
# 5990     ZIMBABWE  161.13  13.59      174.72        147.54
# 5991     ZIMBABWE  175.72   5.71      181.42        170.01
# 5992     ZIMBABWE  200.49   7.77      208.27        192.72
# 5993     ZIMBABWE   50.17   0.61       50.78         49.57
#
#       Financial Year(start) Financial Year(end)
# 0                      1997                1998
# 1                      1998                1999
# 2                      1999                2000
# 3                      2000                2001
# ...

# %%
# Percentage of missing values round by two digit after decimal.
#Reason behind to check whether it can be droped.
round(trade.isnull().mean()*100,2)
# Out:
# Country                  0.00
# Export                   0.13
# Import                   9.21
# Total Trade              9.76
# Trade Balance            9.78
# Financial Year(start)    0.00
# Financial Year(end)      0.00
# dtype: float64

# %% [markdown]
# #### dropna(): TO remove the null values..

# %%
# Drop null
trade = trade.dropna()
trade.head()
# Out:
#        Country Export Import Total Trade Trade Balance  Financial Year(start)  \
# 0  AFGHANISTAN  21.25   10.7       31.95         10.55                   1997
# 1  AFGHANISTAN  12.81  28.14       40.95        -15.33                   1998
# 2  AFGHANISTAN   33.2  21.06       54.26         12.15                   1999
# 3  AFGHANISTAN  25.86  26.59       52.45         -0.73                   2000
# 4  AFGHANISTAN  24.37  17.52       41.89          6.85                   2001
#
#   Financial Year(end)
# 0                1998
# 1                1999
# 2                2000
# 3                2001
# 4                2002

# %%
trade.dtypes # before conversion these are the data types
# Out:
# Country                  object
# Export                   object
# Import                   object
# Total Trade              object
# Trade Balance            object
# Financial Year(start)     int64
# Financial Year(end)      object
# dtype: object

# %%
# Remove all ',' 
trade['Export'] = trade['Export'].str.replace(',','')
trade['Import'] = trade['Import'].str.replace(',','')
trade['Total Trade'] = trade['Total Trade'].str.replace(',','')
trade['Trade Balance'] = trade['Trade Balance'].str.replace(',','')

# %%
# changed data type for calculation
trade['Export'] = trade['Export'].astype('float')
trade['Import'] = trade['Import'].astype('float')
trade['Total Trade'] = trade['Total Trade'].astype('float')
trade['Trade Balance'] = trade['Trade Balance'].astype('float')
trade.dtypes
# Out:
# Country                   object
# Export                   float64
# Import                   float64
# Total Trade              float64
# Trade Balance            float64
# Financial Year(start)      int64
# Financial Year(end)       object
# dtype: object

# %%
trade1=pd.read_csv("imports and exports.csv")
trade1 # storing data into another data frame
# Out:
#           Country Exporting Importing Total Trade Trade Balance  \
# 0     AFGHANISTAN     21.25      10.7       31.95         10.55
# 1     AFGHANISTAN     12.81     28.14       40.95        -15.33
# 2     AFGHANISTAN      33.2     21.06       54.26         12.15
# 3     AFGHANISTAN     25.86     26.59       52.45         -0.73
# 4     AFGHANISTAN     24.37     17.52       41.89          6.85
# ...           ...       ...       ...         ...           ...
# 5989     ZIMBABWE    181.72      7.79      189.51        173.93
# 5990     ZIMBABWE    161.13     13.59      174.72        147.54
# 5991     ZIMBABWE    175.72      5.71      181.42        170.01
# 5992     ZIMBABWE    200.49      7.77      208.27        192.72
# 5993     ZIMBABWE     50.17      0.61       50.78         49.57
#
#       Financial Year(start) Financial Year(end)
# 0                      1997                1998
# 1                      1998                1999
# 2                      1999                2000
# ...

# %% [markdown]
# ### Grouping

# %%
#Groupby
gp=trade1.groupby('Total Trade')
gp

# %%
gp.ngroups
# Out:
# 4603

# %%
# to print single group name records 
gp.get_group('0.61')
# Out:
#           Country Exporting Importing Total Trade Trade Balance  \
# 98    AMERI SAMOA      0.31       0.3        0.61          0.01
# 715   BR VIRGN IS      0.43      0.17        0.61          0.26
# 2193         GUAM      0.54      0.07        0.61          0.47
# 4537   SAN MARINO      0.23      0.39        0.61         -0.16
#
#       Financial Year(start) Financial Year(end)
# 98                     2017                2018
# 715                    2007                2008
# 2193                   2008                2009
# 4537                   2016                2017

# %% [markdown]
# ### Trends in Imports and Exports

# %%
top_ten = trade.nlargest(10, ['Export'])
# nlargest method returns a specified number of rows ,starting from top after sorting the data frame

# %%
sns.relplot(
    data=top_ten, 
    x="Export", y="Import", hue="Country",
    height=5, aspect=2.4, 
    kind="line"
).set(
    title="Total Trade", 
    ylabel="Import",
    xlabel="Export"
)
# hue is used to visualize the data of different categories in one plot

# %%
top_ten = trade.nlargest(10, ['Import'])

# %%
sns.relplot(
    data=top_ten, 
    x="Import", y="Export", hue="Country",
    height=5, aspect=2.4, 
    kind="line"
).set(
    title="Total Trade", 
    ylabel="Export",
    xlabel="Import"
)

# %% [markdown]
# ### scatter plot between imports and exports

# %%
plt.scatter(trade.Import,trade.Export,alpha=0.1)#to check density of plots
plt.title("Imports vs Exports")
plt.xlabel("Imports")
plt.ylabel("Exports")
# Out:
# Text(0, 0.5, 'Exports')

# %% [markdown]
# ### scatter plot to show relation between Total Trade and Trade Balance plotted based on Financial year(start)

# %%
sns.scatterplot(x="Total Trade",y="Trade Balance",hue="Financial Year(start)",data=trade)
#relation between Total Trade and Trade Balance ploted based on Financial year(start)
# Out:
# <Axes: xlabel='Total Trade', ylabel='Trade Balance'>

# %% [markdown]
# ### scatter plot to show relation between Total Trade and Trade Balance plotted based on Financial year(end)

# %%
sns.scatterplot(x="Total Trade",y="Trade Balance",hue="Financial Year(end)",data=trade)
# Out:
# <Axes: xlabel='Total Trade', ylabel='Trade Balance'>

# %% [markdown]
# ### regression plot blw imports and exports

# %%
#regression plot
sns.regplot(x="Import",y="Export",data=trade)
# Out:
# <Axes: xlabel='Import', ylabel='Export'>

# %% [markdown]
# ### Lmplot to show relation between Total Trade and Trade Balance plotted based on Financial year(start)

# %%
#lmplot
sns.lmplot(x="Total Trade",y="Trade Balance",hue="Financial Year(start)",data=trade)

# %%
by_cnt=trade.Country.value_counts()

# %%
by_cnt
# Out:
# AFGHANISTAN           26
# LITHUANIA             26
# MACEDONIA             26
# MADAGASCAR            26
# MALAWI                26
#                       ..
# CHANNEL IS             4
# Petroleum Products     3
# PACIFIC IS             1
# CANARY IS              1
# GUERNSEY               1
# Name: Country, Length: 243, dtype: int64

# %%
by_cnt=trade.Country.value_counts()
top_10_cnt=by_cnt[:10]
top_10_cnt
# Out:
# AFGHANISTAN    26
# LITHUANIA      26
# MACEDONIA      26
# MADAGASCAR     26
# MALAWI         26
# MALAYSIA       26
# MALDIVES       26
# MALI           26
# MALTA          26
# MAURITIUS      26
# Name: Country, dtype: int64

# %% [markdown]
# ### bar graph for top 10 trading countries

# %%
top_10_cnt.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Pie Graph for top 10 trading countries

# %%
top_10_cnt.plot(kind='pie')
# Out:
# <Axes: ylabel='Country'>

# %% [markdown]
# ### just to show some variation between other countries

# %%
by_cnt=trade.Country.value_counts()
btw_180_t0_200=by_cnt[180:200]
btw_180_t0_200
# Out:
# ANTIGUA                         21
# BELIZE                          21
# NETHERLANDANTIL                 21
# EQUTL GUINEA                    21
# RWANDA                          20
# MARSHALL ISLAND                 20
# GUADELOUPE                      20
# MARTINIQUE                      20
# MONACO                          20
# ANDORRA                         19
# UNION OF SERBIA & MONTENEGRO    19
# ERITREA                         19
# CAYMAN IS                       19
# CAPE VERDE IS                   18
# CHRISTMAS IS.                   18
# FR POLYNESIA                    18
# ST HELENA                       18
# TOKELAU IS                      18
# ST LUCIA                        18
# BERMUDA                         18
# Name: Country, dtype: int64

# %%
btw_180_t0_200.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### displot() for financial year (start)

# %%
#displot() depicts the variation in data distribution
sns.displot(data=trade,x='Financial Year(start)',color='purple',bins=15,kde=True,rug=True)
#bins = no of bars
#kde kernel density estimation
# rug to plot marginal distributions

# %% [markdown]
# ### joint plot() between financial years

# %%
#joint plot() -> used to subplot grid for plotting pairwise relationships in a data sets
sns.jointplot(data=trade,x='Financial Year(start)',y='Financial Year(end)')

# %% [markdown]
# ### joint plot() between financial year and trade balance

# %%
sns.jointplot(data=trade,x='Financial Year(start)',y='Trade Balance',color='purple',kind='hex')

# %%
sns.jointplot(data=trade,x='Financial Year(start)',y='Trade Balance',kind='kde')
#inside normal distribution of scatter plot
#outside normal distribution of each variable

# %%
sns.jointplot(data=trade,x='Financial Year(start)',y='Export',hue='Import')

# %% [markdown]
# ### Heat map

# %%
numeric_columns = trade.select_dtypes(include='number') # this function not to get warnings
plt.figure(figsize=(15,7))
sns.heatmap(numeric_columns.corr(), annot=True)
# Out:
# <Axes: >
